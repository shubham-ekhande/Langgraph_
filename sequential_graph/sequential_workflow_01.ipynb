# %%
from langgraph.graph import StateGraph, START, END
from langchain_ollama import ChatOllama
from typing import TypedDict

# %%
model = ChatOllama(
    model="llama3.2:1b",
    base_url="http://127.0.0.1:11434",
    temperature=0.7
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
print(type(model))
# Out:
# <class 'langchain_ollama.chat_models.ChatOllama'>

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here\'s a detailed outline for a blog on the rise of AI in India:\n\n**I. Introduction**\n\n* Brief overview of the importance of Artificial Intelligence (AI) and its growing presence globally\n* Context: India\'s rapid growth, increasing demand for digital solutions, and government initiatives to boost innovation\n* Thesis statement: The rise of AI in India is transforming various sectors, from healthcare to manufacturing, with significant economic and social benefits.\n\n**II. Drivers of the AI Revolution in India**\n\n* Economic factors:\n\t+ Government\'s "Make in India" initiative to attract foreign investment and create jobs\n\t+ Growing demand for digital solutions to address labor shortages and improve productivity\n* Technological advancements:\n\t+ Rapid development of AI frameworks, libraries, and tools (e.g., TensorFlow, PyTorch)\n\t+ Advancements in machine learning, deep learning, and natural language processing\n* Social factors:\n\t+ Increasing awareness about the benefits and challenges of AI\n\t+ Growing interest in STEM education and training\n\n**III. Applications of AI in India**\n\n* Healthcare:\n\t+ Artificial diagnosis systems for disease detection and treatment\n\t+ Personalized medicine using machine learning algorithms\n\t+ Predictive analytics for patient outcomes and resource allocation\n* Manufacturing:\n\t+ Predictive maintenance using IoT sensors and machine learning\n\t+ Quality control and inspection using AI-powered tools\n\t+ Supply chain optimization using data analytics\n* Education:\n\t+ Adaptive learning systems for personalized education\n\t+ Intelligent tutoring systems for student support\n\t+ Content creation and curation using AI-powered tools\n\n**IV. Challenges and Limitations**\n\n* Job displacement: Concerns about AI replacing human workers in various sectors\n* Data privacy and security: Ensuring the secure storage, processing, and sharing of sensitive data\n* Accessibility: Addressing digital divide and ensuring that all citizens have access to AI-based solutions\n* Ethics and governance: Developing frameworks for responsible AI development and deployment\n\n**V. Government Initiatives and Support**\n\n* Government\'s "Digital India" program to promote AI adoption across sectors\n* Creation of AI-specific funds, grants, and schemes (e.g., "Make in AI")\n* Collaboration with academia, industry, and civil society organizations\n* Development of guidelines and standards for AI development and deployment\n\n**VI. Industry Initiatives and Partnerships**\n\n* Startups and entrepreneurs partnering with government agencies to develop AI-based solutions\n* Large corporations investing in AI research and development\n* Collaboration with other industries (e.g., finance, transportation) to leverage AI benefits\n* Development of industry-specific standards and frameworks for AI adoption\n\n**VII. Impact on Society and Economy**\n\n* Economic growth: Increased productivity, competitiveness, and job creation\n* Social impact: Improved healthcare outcomes, increased access to education, and enhanced customer experiences\n* Societal changes: Shifts in workforce demographics, changing consumption patterns, and new forms of entrepreneurship\n\n**VIII. Conclusion**\n\n* Recap of the rise of AI in India and its transformative potential\n* Reflection on the challenges and limitations that need to be addressed\n* Call to action for continued investment, innovation, and collaboration to maximize the benefits of AI in India.\n\nThis outline should provide a solid foundation for your blog post on the rise of AI in India.', 'content': 'Here\'s a detailed blog on the title "Rise of AI in India using the following outline:\n\n**I. Introduction**\n\n* Brief overview of the importance of Artificial Intelligence (AI) and its growing presence globally\n* Context: India\'s rapid growth, increasing demand for digital solutions, and government initiatives to boost in ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog on the rise of AI in India:
#
# **I. Introduction**
#
# * Brief overview of the importance of Artificial Intelligence (AI) and its growing presence globally
# * Context: India's rapid growth, increasing demand for digital solutions, and government initiatives to boost innovation
# * Thesis statement: The rise of AI in India is transforming various sectors, from healthcare to manufacturing, with significant economic and social benefits.
#
# **II. Drivers of the AI Revolution in India**
#
# * Economic factors:
# 	+ Government's "Make in India" initiative to attract foreign investment and create jobs
# 	+ Growing demand for digital solutions to address labor shortages and improve productivity
# * Technological advancements:
# 	+ Rapid development of AI frameworks, libraries, and tools (e.g., TensorFlow, PyTorch)
# 	+ Advancements in machine learning, deep learning, and natural language processing
# * Social factors:
# 	+ Increasing awareness about the benefits and challenges of AI
# 	+ Growing interest in STEM education and training
#
# **III. Applications of AI in India**
#
# * Healthcare:
# 	+ Artificial diagnosis systems for disease detection and treatment
# 	+ Personalized medicine using machine learning algorithms
# 	+ Predictive analytics for patient outcomes and resource allocation
# * Manufacturing:
# 	+ Predictive maintenance using IoT sensors and machine learning
# 	+ Quality control and inspection using AI-powered tools
# 	+ Supply chain optimization using data analytics
# * Education:
# 	+ Adaptive learning systems for personalized education
# 	+ Intelligent tutoring systems for student support
# 	+ Content creation and curation using AI-powered tools
#
# **IV. Challenges and Limitations**
#
# * Job displacement: Concerns about AI replacing human workers in various sectors
# * Data privacy and security: Ensuring the secure storage, processing, and sharing of sensitive data
# * Accessibility: Addressing digital divide and ensuring that all citizens have access to AI-based solutions
# * Ethics and governance: Developing frameworks for responsible AI development and deployment
#
# **V. Government Initiatives and Support**
#
# * Government's "Digital India" program to promote AI adoption across sectors
# * Creation of AI-specific funds, grants, and schemes (e.g., "Make in AI")
# * Collaboration with academia, industry, and civil society organizations
# * Development of guidelines and standards for AI development and deployment
#
# **VI. Industry Initiatives and Partnerships**
#
# * Startups and entrepreneurs partnering with government agencies to develop AI-based solutions
# * Large corporations investing in AI research and development
# * Collaboration with other industries (e.g., finance, transportation) to leverage AI benefits
# * Development of industry-specific standards and frameworks for AI adoption
#
# **VII. Impact on Society and Economy**
#
# * Economic growth: Increased productivity, competitiveness, and job creation
# * Social impact: Improved healthcare outcomes, increased access to education, and enhanced customer experiences
# * Societal changes: Shifts in workforce demographics, changing consumption patterns, and new forms of entrepreneurship
#
# **VIII. Conclusion**
#
# * Recap of the rise of AI in India and its transformative potential
# * Reflection on the challenges and limitations that need to be addressed
# * Call to action for continued investment, innovation, and collaboration to maximize the benefits of AI in India.
#
# This outline should provide a solid foundation for your blog post on the rise of AI in India.

# %%
print(final_state['content'])
# Out:
# Here's a detailed blog on the title "Rise of AI in India using the following outline:
#
# **I. Introduction**
#
# * Brief overview of the importance of Artificial Intelligence (AI) and its growing presence globally
# * Context: India's rapid growth, increasing demand for digital solutions, and government initiatives to boost innovation
# * Thesis statement: The rise of AI in India is transforming various sectors, from healthcare to manufacturing, with significant economic and social benefits.
#
# **II. Drivers of the AI Revolution in India**
#
# * Economic factors:
# 	+ Government's "Make in India" initiative to attract foreign investment and create jobs
# 	+ Growing demand for digital solutions to address labor shortages and improve productivity
# * Technological advancements:
# 	+ Rapid development of AI frameworks, libraries, and tools (e.g., TensorFlow, PyTorch)
# 	+ Advancements in machine learning, deep learning, and natural language processing
# * Social factors:
# 	+ Increasing awareness about the benefits and challenges of AI
# 	+ Growing interest in STEM education and training
#
# **III. Applications of AI in India**
#
# * Healthcare:
# 	+ Artificial diagnosis systems for disease detection and treatment
# 	+ Personalized medicine using machine learning algorithms
# 	+ Predictive analytics for patient outcomes and resource allocation
# * Manufacturing:
# 	+ Predictive maintenance using IoT sensors and machine learning
# 	+ Quality control and inspection using AI-powered tools
# 	+ Supply chain optimization using data analytics
# * Education:
# 	+ Adaptive learning systems for personalized education
# 	+ Intelligent tutoring systems for student support
# 	+ Content creation and curation using AI-powered tools
#
# **IV. Challenges and Limitations**
#
# * Job displacement: Concerns about AI replacing human workers in various sectors
# * Data privacy and security: Ensuring the secure storage, processing, and sharing of sensitive data
# * Accessibility: Addressing digital divide and ensuring that all citizens have access to AI-based solutions
# * Ethics and governance: Developing frameworks for responsible AI development and deployment
#
# **V. Government Initiatives and Support**
#
# * Government's "Digital India" program to promote AI adoption across sectors
# * Creation of AI-specific funds, grants, and schemes (e.g., "Make in AI")
# * Collaboration with academia, industry, and civil society organizations
# * Development of guidelines and standards for AI development and deployment
#
# **VI. Industry Initiatives and Partnerships**
#
# * Startups and entrepreneurs partnering with government agencies to develop AI-based solutions
# * Large corporations investing in AI research and development
# * Collaboration with other industries (e.g., finance, transportation) to leverage AI benefits
# * Development of industry-specific standards and frameworks for AI adoption
#
# **VII. Impact on Society and Economy**
#
# * Economic growth: Increased productivity, competitiveness, and job creation
# * Social impact: Improved healthcare outcomes, increased access to education, and enhanced customer experiences
# * Societal changes: Shifts in workforce demographics, changing consumption patterns, and new forms of entrepreneurship
#
# **VIII. Conclusion**
#
# * Recap of the rise of AI in India and its transformative potential
# * Reflection on the challenges and limitations that need to be addressed
# * Call to action for continued investment, innovation, and collaboration to maximize the benefits of AI in India.
#
# In conclusion, the rise of AI in India is a significant trend with far-reaching consequences for various sectors. While there are challenges and limitations that need to be addressed, the potential benefits of AI adoption in India are substantial, and policymakers, industry leaders, and citizens must work together to unlock its full potential.
#
# I hope this outline provides a solid foundation for your blog post on the rise of AI in India.
